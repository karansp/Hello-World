# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

data_path = r"C:\Users\Asus\OneDrive\Documents\Data science\world-happiness-report-2019.csv"
data = pd.read_csv(data_path)

##print(data.head())

##print(data.columns)

plt.figure(figsize=(8,80))
sns.barplot(x = data['Corruption'],y = data['Country (region)'])

# %%
data
# Out:
#              Country (region)  Ladder  SD of Ladder  Positive affect  \
# 0                     Finland       1             4             41.0
# 1                     Denmark       2            13             24.0
# 2                      Norway       3             8             16.0
# 3                     Iceland       4             9              3.0
# 4                 Netherlands       5             1             12.0
# 5                 Switzerland       6            11             44.0
# 6                      Sweden       7            18             34.0
# 7                 New Zealand       8            15             22.0
# 8                      Canada       9            23             18.0
# 9                     Austria      10            10             64.0
# 10                  Australia      11            26             47.0
# 11                 Costa Rica      12            62              4.0
# 12                     Israel      13            14            104.0
# ...

# %%
#sns.scatterplot( x = data['Log of GDP per capita'] , y = data['Healthy life expectancy'])
data.dropna()
#print(data.describe())
# Out:
#              Country (region)  Ladder  SD of Ladder  Positive affect  \
# 0                     Finland       1             4             41.0
# 1                     Denmark       2            13             24.0
# 2                      Norway       3             8             16.0
# 3                     Iceland       4             9              3.0
# 4                 Netherlands       5             1             12.0
# 5                 Switzerland       6            11             44.0
# 6                      Sweden       7            18             34.0
# 7                 New Zealand       8            15             22.0
# 8                      Canada       9            23             18.0
# 9                     Austria      10            10             64.0
# 10                  Australia      11            26             47.0
# 11                 Costa Rica      12            62              4.0
# 12                     Israel      13            14            104.0
# ...

# %%
sns.scatterplot( x = data['Freedom'] , y = data['Generosity'])
sns.regplot( x = data['Freedom'] , y = data['Generosity'])

# %%
plt.figure(figsize=(30,10))

sns.swarmplot( x = data['Freedom'] , y = data['Generosity'])

# %%
plt.figure(figsize=(35,10))

sns.lineplot( x = data['Freedom'] , y = data['Generosity'])
